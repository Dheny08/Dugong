# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheny08/Dugong/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data_url="http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
features = np.hstack ([raw_df.values[::2,:], raw_df.values[1::2,:2]])
target = raw_df.values[1::2, 2]
feature_names =[
"CRIM",
"ZN",
"INDUS",
"CHAS",
"NOX",
"RM",
"AGE",
"DIS",
"RAD",
"TAX",
"PTRATIO",
"B",
"LSTAT",]

print("Features shape:", features.shape)
print("Target shape:", target.shape)
# Out:
# Features shape: (506, 13)
# Target shape: (506,)

# %%
df_housing = pd.DataFrame (features)
df_housing.columns = feature_names
df_housing['MEDV'] = target
df_housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df_housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
xtrain, xtest, ytrain, ytest = train_test_split(features, target, test_size=0.4, random_state=1)
print(xtrain. shape, xtest.shape)
print(ytrain. shape, ytest.shape)
# Out:
# (303, 13) (203, 13)
# (303,) (203,)

# %%
scaler=MinMaxScaler()
xstrain=scaler.fit_transform(xtrain)
xstest=scaler.transform(xtest)

# %%
lr=LinearRegression()
lr.fit(xstrain, ytrain)
print('constant term:', lr.intercept_)
print('coefficients:', lr.coef_)
# Out:
# constant term: 25.572341408049475
# coefficients: [ -6.58598655   6.73132853   1.37668315   2.18579583  -8.24138541
#   16.48957721   0.19324514 -15.01197421   6.66026451  -6.42948378
#   -7.84788938   3.72928282 -17.65541145]

# %%
ypred=lr.predict(xstest)
mse=mean_squared_error(ytest, ypred)
r2=lr.score (xstest, ytest)

# %%
plt.figure()
plt.scatter (ytest, ypred)
plt.xlabel('target output')
plt.ylabel('prediksi target')
plt.show()

# %%
df_hasil =pd.DataFrame({'Data sebenarnya': ytest, 'Data prediksi': ypred})
df_hasil
# Out:
#      Data sebenarnya  Data prediksi
# 0               28.2      32.576784
# 1               23.9      28.315840
# 2               16.6      18.024909
# 3               22.0      21.227239
# 4               20.8      18.307063
# ..               ...            ...
# 198             50.0      34.818083
# 199             50.0      25.369789
# 200             18.4      18.818492
# 201             17.9       2.520984
# 202             28.1      24.888448
#
# [203 rows x 2 columns]

# %%
polynomial=PolynomialFeatures (degree=2, include_bias=False)
xsptrain=polynomial.fit_transform(xstrain)
xsptest=polynomial.transform(xstest)

# %%
lr=LinearRegression()
lr.fit(xsptrain, ytrain)
print('cosntant term:', lr.intercept_)
print('coefficients:', lr.coef_)
# Out:
# cosntant term: -35.86119001566591
# coefficients: [ 4.79377133e+01  4.60397241e+00 -4.73198873e+01  5.07913180e+00
#   8.45082887e+00  5.94256332e+01  3.19106813e+01 -1.87635657e+01
#   5.48986300e+01 -6.21472678e+00 -1.61181541e-01  5.18400638e+01
#   4.92379894e+01  1.90120087e+01 -9.32092915e+01 -3.32220481e+02
#   1.17861591e+02 -6.75233793e+01  1.36642031e+02 -5.22041184e+01
#  -1.54086281e+02 -5.58377051e+02  7.77933364e+02 -1.05273233e+01
#  -4.61881990e+00  6.95076946e+01 -1.21739733e+00 -1.89619491e+01
#  -1.74119670e+01 -9.14512301e+01 -1.31013139e+00  1.10347106e+01
#  -3.62737843e+01 -1.61916372e+00  1.98053806e+01  1.73748901e+01
#   1.35455276e+01 -2.24377571e+01  1.58075285e+01 -6.10049159e+00
#   3.69386712e+01  1.51235277e+01  7.49808727e+00  5.91003993e+01
#  -1.18482457e+01  1.95828609e+01  1.91708188e+01 -9.25398292e+00
#  -7.46719162e+00  5.07913180e+00 -1.62500680e+01 -1.71183284e+01
#   1.91279473e+00  3.85947943e+01 -1.91127580e+01  3.29062914e+01
# ...

# %%
ypred=lr.predict(xsptest)
mse=mean_squared_error(ytest, ypred)
r2=lr.score (xsptest, ytest)
print('MSE:', mse)
print('R^2:', r2)
# Out:
# MSE: 21.043418904497248
# R^2: 0.7669939120324855

# %%
plt.figure()
plt.scatter (ytest, ypred)
plt.xlabel('target output')
plt.ylabel('prediksi target')
plt.show()
